# %% [markdown]
# <a href="https://colab.research.google.com/github/Ol8410/Datasets/blob/master/%D0%9F%D1%80%D0%BE%D0%B3%D0%BD%D0%BE%D0%B7_%D0%BA%D0%B0%D1%87%D0%B5%D1%81%D1%82%D0%B2%D0%B0_%D0%B2%D0%BE%D0%B4%D1%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Прогноз качества воды - точность 76% и H2O-80%**

# %% [markdown]
# Все растения и животные нуждаются в воде, чтобы выжить. Без воды на земле не может быть жизни. Почему вода так важна? Потому что 60 процентов веса нашего тела состоит из воды. Наш организм использует воду во всех клетках, органах и тканях, чтобы помочь регулировать температуру тела и поддерживать другие функции организма. Поскольку наш организм теряет воду при дыхании, потоотделении и пищеварении, крайне важно проводить регидратацию и заменять воду, выпивая жидкости и употребляя продукты, содержащие воду.
# Давайте рассмотрим все способы воздействия воды на нашу жизнь…
#
# 1. Вода регулирует температуру тела
#
# 2. Вода улучшает когнитивные функции
#
# 3. Вода защищает ткани, спинной мозг и суставы
#
# 4. Вода максимизирует нашу физическую работоспособность
#
# 5. Это помогает повысить наш энергетический уровень
#
# 6. Вода предотвращает общее обезвоживание

# %% [markdown]
# Постановка задачи:
#
# Классифицировать качество воды, пригодна ли она для питья или нет, на основе предоставленных характеристик.
# Feature Details/ Детали функции
#
# 1. Значение рН (pH value: ): РН является важным параметром при оценке кислотно–щелочного баланса воды. Это также индикатор кислотного или щелочного состояния воды. ВОЗ рекомендовала максимально допустимый предел рН от 6,5 до 8,5. Текущие диапазоны исследования составляли 6,52–6,83, что соответствует стандартам ВОЗ.
#
# 2. Твердость(Hardness): Твердость в основном обусловлена солями кальция и магния. Эти соли растворяются в геологических отложениях, через которые проходит вода. Продолжительность контакта воды с материалом, придающим жесткость, помогает определить, насколько жестка сырая вода. Жесткость первоначально определялась как способность воды осаждать мыло, вызванная кальцием и магнием.
#
# 3. Твердые вещества (Solids) (Общее количество растворенных твердых веществ - TDS): Вода обладает способностью растворять широкий спектр неорганических и некоторых органических минералов или солей, таких как калий, кальций, натрий, бикарбонаты, хлориды, магний, сульфаты и т.д. Эти минералы придавали воде нежелательный вкус и разбавленный цвет. Это важный параметр для использования воды. Вода с высоким значением TDS указывает на то, что вода сильно минерализована. Желаемый предел для TDS составляет 500 мг/л, а максимальный предел составляет 1000 мг/л, который предписан для употребления в пищу.
#
# 4. Хлорамины (Chloramines): Хлор и хлорамин являются основными дезинфицирующими средствами, используемыми в системах общественного водоснабжения. Хлорамины чаще всего образуются при добавлении аммиака к хлору для обработки питьевой воды. Содержание хлора в питьевой воде до 4 миллиграммов на литр (мг/л или 4 части на миллион (ppm)) считается безопасным.
#
# 5. Сульфат (Sulfate): Сульфаты - это природные вещества, которые содержатся в минералах, почве и горных породах. Они присутствуют в окружающем воздухе, грунтовых водах, растениях и продуктах питания. Основное коммерческое применение сульфата - в химической промышленности. Концентрация сульфата в морской воде составляет около 2700 миллиграммов на литр (мг/л). В большинстве источников пресной воды она колеблется от 3 до 30 мг/л, хотя в некоторых географических точках встречаются гораздо более высокие концентрации (1000 мг/л).
#
# 6. Проводимость (Conductivity): Чистая вода не является хорошим проводником электрического тока, скорее это хороший изолятор. Увеличение концентрации ионов повышает электропроводность воды. Как правило, количество растворенных твердых веществ в воде определяет электропроводность. Электрическая проводимость (EC) фактически измеряет ионный процесс раствора, который позволяет ему пропускать ток. Согласно стандартам ВОЗ, значение EC не должно превышать 400 мкс/см
#
# 7. Органический карбон (Organic carbon): Общий органический углерод (TOC) в исходных водах поступает из разлагающегося природного органического вещества (NOM), а также из синтетических источников. TOC - это показатель общего количества углерода в органических соединениях в чистой воде. Согласно EPA США < 2 мг / л в качестве TOC в очищенной / питьевой воде и < 4 мг / л в исходной воде, которая используется для лечения.
#
# 8. Тригалометаны (Trihalomethanes): ТГМ - это химические вещества, которые могут содержаться в воде, обработанной хлором. Концентрация ТГМ в питьевой воде варьируется в зависимости от уровня органического вещества в воде, количества хлора, необходимого для очистки воды, и температуры обрабатываемой воды. Уровень ТГМ до 80 промилле считается безопасным в питьевой воде.
#
# 9. Мутность (Turbidity): Мутность воды зависит от количества твердого вещества, присутствующего во взвешенном состоянии. Это показатель светоизлучающих свойств воды, и тест используется для определения качества сброса отходов по отношению к коллоидному веществу. Среднее значение мутности, полученное для кампуса Wondo Genet (0,98 NTU), ниже рекомендованного ВОЗ значения в 5,00 NTU.
#
# 11.	Пригодность для питья (Potability): Указывает, безопасна ли вода для потребления человеком, где 1 означает Пригодную для питья, а 0 означает Непригодную для питья.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# Считывание Данных

# %%
df= pd.read_csv("/content/drive/MyDrive/water_potability.csv")

# %%
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %% [markdown]
# Существует 9 независимых функций и 1 зависимая функция. Подробная информация по каждому элементу приведена в верхней части выше. Цель состоит в том, чтобы использовать функцию пригодности для питья в качестве целевого элемента для задачи классификации. Проведем дополнительный анализ, чтобы лучше изучить набор данных.

# %% [markdown]
# Тип данных объектов

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df['Potability']=df['Potability'].astype('category')

# %%
#создаем лимит одобрения для каждой функции на основе данных, доступных в поиске
cols=df.columns[0:9].to_list()
min_val=[6.52,0,500,0,3,0,0,0,0]
max_val=[6.83,0,1000,4,250,400,2,80,5]
limit=pd.DataFrame(data=[min_val, max_val], columns=cols)

# %% [markdown]
# Статистический анализ

# %%
df.describe().T.style.background_gradient(subset=['mean','std','50%','count'], cmap='PuBu')
# Out:
# <style type="text/css">
# #T_fa342_row0_col0 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_fa342_row0_col1, #T_fa342_row0_col2, #T_fa342_row0_col5, #T_fa342_row1_col2, #T_fa342_row3_col1, #T_fa342_row3_col2, #T_fa342_row3_col5, #T_fa342_row4_col0, #T_fa342_row6_col1, #T_fa342_row6_col2, #T_fa342_row6_col5, #T_fa342_row7_col1, #T_fa342_row7_col2, #T_fa342_row7_col5, #T_fa342_row8_col1, #T_fa342_row8_col2, #T_fa342_row8_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_fa342_row1_col0, #T_fa342_row2_col0, #T_fa342_row2_col1, #T_fa342_row2_col2, #T_fa342_row2_col5, #T_fa342_row3_col0, #T_fa342_row5_col0, #T_fa342_row6_col0, #T_fa342_row8_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_fa342_row1_col1, #T_fa342_row1_col5, #T_fa342_row5_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_fa342_row4_col1, #T_fa342_row4_col5, #T_fa342_row5_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_fa342_row4_col2 {
# ...

# %% [markdown]
# Из приведенной выше таблицы можем видеть, что количество каждой функции неодинаково. таким образом, должны быть какие-то нулевые значения.
# Признак Solids имеет высокое среднее значение и стандартное отклонение по сравнению с другим признаком. таким образом, распределение должно быть высоким.
# Однако приведенное выше описание относится к общей численности населения. давайте попробуем то же самое для 2 образцов, основанных на функции переносимости

# %%
#Переносимость равна 1 - означает пользу для человека
df[df['Potability']==1].describe().T.style.background_gradient(subset=['mean','std','50%','count'], cmap='PuBu')
# Out:
# <style type="text/css">
# #T_7050b_row0_col0 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_7050b_row0_col1, #T_7050b_row0_col2, #T_7050b_row0_col5, #T_7050b_row1_col2, #T_7050b_row3_col1, #T_7050b_row3_col2, #T_7050b_row3_col5, #T_7050b_row4_col0, #T_7050b_row6_col1, #T_7050b_row6_col2, #T_7050b_row6_col5, #T_7050b_row7_col1, #T_7050b_row7_col2, #T_7050b_row7_col5, #T_7050b_row8_col1, #T_7050b_row8_col2, #T_7050b_row8_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_7050b_row1_col0, #T_7050b_row2_col0, #T_7050b_row2_col1, #T_7050b_row2_col2, #T_7050b_row2_col5, #T_7050b_row3_col0, #T_7050b_row5_col0, #T_7050b_row6_col0, #T_7050b_row8_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_7050b_row1_col1, #T_7050b_row1_col5, #T_7050b_row5_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_7050b_row4_col1, #T_7050b_row4_col5, #T_7050b_row5_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_7050b_row4_col2 {
# ...

# %%
#Переносимость равна 0 - значит, не подходит для человека
df[df['Potability']==0].describe().T.style.background_gradient(subset=['mean','std','50%','count'], cmap='RdBu')
# Out:
# <style type="text/css">
# #T_acd74_row0_col0 {
#   background-color: #f9c4a9;
#   color: #000000;
# }
# #T_acd74_row0_col1, #T_acd74_row0_col2, #T_acd74_row0_col5, #T_acd74_row1_col2, #T_acd74_row3_col1, #T_acd74_row3_col2, #T_acd74_row3_col5, #T_acd74_row4_col0, #T_acd74_row6_col1, #T_acd74_row6_col2, #T_acd74_row6_col5, #T_acd74_row7_col1, #T_acd74_row7_col2, #T_acd74_row7_col5, #T_acd74_row8_col1, #T_acd74_row8_col2, #T_acd74_row8_col5 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_acd74_row1_col0, #T_acd74_row2_col0, #T_acd74_row2_col1, #T_acd74_row2_col2, #T_acd74_row2_col5, #T_acd74_row3_col0, #T_acd74_row5_col0, #T_acd74_row6_col0, #T_acd74_row8_col0 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_acd74_row1_col1, #T_acd74_row1_col5, #T_acd74_row5_col2 {
#   background-color: #6d0220;
#   color: #f1f1f1;
# }
# #T_acd74_row4_col1 {
#   background-color: #700320;
#   color: #f1f1f1;
# }
# #T_acd74_row4_col2 {
#   background-color: #6a011f;
# ...

# %% [markdown]
# Среднее значение и std почти по всем признакам одинаковы для обеих выборок. в функции твердых тел есть несколько различий. Дальнейший анализ с использованием гипотетического тестирования мог бы помочь нам определить значимость.

# %% [markdown]
# Проверим наличие пропущенных значений

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %% [markdown]
# Характеристики рн, сульфат и тригалометаны имеют нулевые значения. давайте проверим это в деталях и найдем вариант

# %%
df[df['Sulfate'].isnull()]
df[df['ph'].isnull()]
df[df['Trihalomethanes'].isnull()]
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 62         NaN  229.485694  35729.692709     8.810843  384.943779
# 81    5.519126  168.728583  12531.601921     7.730723         NaN
# 110   9.286155  222.661551  12311.268366     7.289866  332.239359
# 118   7.397413  122.541040   8855.114121     6.888689  241.607532
# 119   7.812804  196.583886  42550.841816     7.334648         NaN
# ...        ...         ...           ...          ...         ...
# 3174  6.698154  198.286268  34675.862845     6.263602  360.232834
# 3185  6.110022  234.800957  16663.539074     5.984536  348.055211
# 3219  6.417716  209.702425  31974.481631     7.263425  321.382124
# 3259  9.271355  181.259617  16540.979048     7.022499  309.238865
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity Potability
# 62      296.397547       16.927092              NaN   3.855602          0
# ...

# %% [markdown]
# Поскольку отсутствующие значения относятся к обоим классам (пригодность для питья 1 и 0), можем заменить их средним значением по населению. итак, заменим значения Nan, основанные на выборочном среднем из обоих классов.

# %%
#Заменим нулевые значения на основе group/sample mean
df['ph']=df['ph'].fillna(df.groupby(['Potability'])['ph'].transform('mean'))
df['Sulfate']=df['Sulfate'].fillna(df.groupby(['Potability'])['Sulfate'].transform('mean'))
df['Trihalomethanes']=df['Trihalomethanes'].fillna(df.groupby(['Potability'])['Trihalomethanes'].transform('mean'))

# %%
df.isna().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %% [markdown]
# Предварительный Анализ Данных

# %%
#Import ploting libraries
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots 
colors = ['#06344d','#00b2ff']
sns.set(palette=colors, font='Serif', style='white', rc={'axes.facecolor':'#f1f1f1', 'figure.facecolor':'#f1f1f1'})
sns.palplot(colors)

# %%
#проверим целевые функции
fig = plt.figure(figsize=(10,6))
ax=sns.countplot(data=df, x='Potability')
for i in ax.patches:
    ax.text(x=i.get_x()+i.get_width()/2, y=i.get_height()/7, s=f"{np.round(i.get_height()/len(df)*100,0)}%", ha='center', size=50, weight='bold', rotation=90, color='white')
plt.title("Характеристика пригодности для питья", size=20, weight='bold')
# Out:
# Text(0.5, 1.0, 'Характеристика пригодности для питья')

# %% [markdown]
# Распределительные участки

# %%
limit
# Out:
#      ph  Hardness  Solids  Chloramines  Sulfate  Conductivity  Organic_carbon  \
# 0  6.52         0     500            0        3             0               0
# 1  6.83         0    1000            4      250           400               2
#
#    Trihalomethanes  Turbidity
# 0                0          0
# 1               80          5

# %%
from matplotlib.patches import Rectangle
int_cols = df.select_dtypes(exclude=['category']).columns.to_list()
fig, ax= plt.subplots(nrows=3,ncols=3,figsize=(15,15), constrained_layout=True)
plt.suptitle('Распределение характеристик по классу пригодности для питья и утвержденному пределу', size=20, weight='bold')
ax=ax.flatten()
for x, i in enumerate(int_cols):
    sns.kdeplot(data=df, x=i, hue='Potability', ax=ax[x], fill=True, multiple='stack', alpha=0.5, linewidth=2)
    l,k = limit.iloc[:,x]
    ax[x].add_patch(Rectangle(xy=(l,0), width=k-l, height=1, alpha=0.5))
    for s in ['left','right','top','bottom']:
        ax[x].spines[s].set_visible(False)

# %% [markdown]
# Основываясь на утвержденном пределе,можем четко видеть разницу в классификации воды. Пример: распределение непитьевой воды отличается высокой электропроводностью по сравнению с питьевой водой. то же самое применимо к мутности, тригалометанам.
# Но значение рН, наличие хлораминов, сульфатов, органического углерода не показывают существенной разницы. Надеюсь, что гипотетическое тестирование может помочь нам здесь.

# %%
fig, ax= plt.subplots(nrows=3,ncols=3,figsize=(15,15), constrained_layout=True)
plt.suptitle('Распределение характеристик по классу пригодности для питья и утвержденному пределу', size=20, weight='bold')
ax=ax.flatten()
for x, i in enumerate(int_cols):
    sns.boxplot(data=df, y=i, x='Potability', ax=ax[x])
    #l,k = limit.iloc[:,x]
    #ax[x].add_patch(Rectangle(xy=(l,0), width=k-l, height=1, alpha=0.5))
    for s in ['left','right','top','bottom']:
        ax[x].spines[s].set_visible(False)

# %% [markdown]
# В наборе данных есть выбросы, нужно обработать то же самое. большинство функциональных средств выглядят одинаково, и разница в отклонениях очень мала. как упоминалось в приведенном выше наблюдении, проверка гипотезы была бы правильным вариантом для определения значимости.

# %% [markdown]
# Проверка гипотезы

# %% [markdown]
# **Ho** (нулевая гипотеза) - Среднее значение для обеих выборок/группы одинаковое
#
# **H1** (альтернативная гипотеза) - Среднее значение для обеих выборок/группы значительно отличается.
#
# **Значительный уровень - 90%**
#
# **Альфа - 0,5% (т.е. 0,1)**

# %%
from scipy.stats import ttest_ind
p_val=[]
for i in int_cols:
    pota_1 = df[df['Potability']==1][i]
    pota_0 = df[df['Potability']==0][i]
    stat, p_value=ttest_ind(pota_1, pota_0)
    p_val.append(np.round(p_value,3))
    if p_value <0.1:
        print(f"p_value for {i} is {p_value} is less than significant value 0.1, so we have no enough evidance to prove Null Hypothesis. so we reject the Null Hypotesis")
    else:
        print(f"p_value for {i} is {p_value} we accept the null hypothesis")

stats_test=pd.DataFrame(columns=['columns','p_value'])
stats_test['columns']=int_cols
stats_test['p_value']=p_val
stats_test.sort_values(by=['p_value'], ascending=True, inplace=True)

fig=plt.figure(figsize=(15,8))
ax=sns.barplot(data=stats_test, x='columns',y='p_value')
plt.title("Характеристики и p_value на основеt-Test", size=20, weight='bold')
for i in ax.patches:
    ax.text(x=i.get_x()+0.5, y=i.get_height(), s=i.get_height(), rotation=90)
ax.axhline(y=0.1, color='red', ls='--')
ax.text(x=6, y=0.12, s="Significance level: 0.1")
# Out:
# p_value for ph is 0.8257362194511633 we accept the null hypothesis
# p_value for Hardness is 0.42854158740864634 we accept the null hypothesis
# p_value for Solids is 0.053463638184504905 is less than significant value 0.1, so we have no enough evidance to prove Null Hypothesis. so we reject the Null Hypotesis
# p_value for Chloramines is 0.17361022465074671 we accept the null hypothesis
# p_value for Sulfate is 0.12292453703923874 we accept the null hypothesis
# p_value for Conductivity is 0.6418845485973537 we accept the null hypothesis
# p_value for Organic_carbon is 0.08599746163873828 is less than significant value 0.1, so we have no enough evidance to prove Null Hypothesis. so we reject the Null Hypotesis
# p_value for Trihalomethanes is 0.675988889793878 we accept the null hypothesis
# p_value for Turbidity is 0.9279391620838058 we accept the null hypothesis
# Text(6, 0.12, 'Significance level: 0.1')

# %%
sns.pairplot(df, hue='Potability', kind='reg')

# %%
fig, ax=plt.subplots(nrows=1, ncols=2, figsize=(15,8))
plt.suptitle("Матрицы взаимосвязей", size=20, weight='bold')
ax=ax.flatten()
sns.heatmap(df[df['Potability']==1].corr(), annot=True, square=True, fmt='.2f', ax=ax[0], cbar=False)
sns.heatmap(df[df['Potability']==0].corr(), annot=True, square=True, fmt='.2f', ax=ax[1], cbar=False)

# %%
fig=plt.figure(figsize=(8,8))
sns.heatmap(df.corr(), annot=True, fmt='0.2f', square=True)

# %% [markdown]
# Как в матрице взаимосвязей, так и в Paiplot говорится, что между функциями, можно объяснить целевую переменную, нет линейной зависимости.
# Таким образом, линейная модель может не работать над этой проблемой, необходимо попробовать использовать вероятностные модели.

# %% [markdown]
# PCA для проверки объясненной дисперсии

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
X = df.drop(['Potability'], axis=1)
y=df['Potability']

scale = StandardScaler()
X_scaled = scale.fit_transform(X)
decom = PCA(svd_solver='auto') #попробуем использовать auto вместо определения компонентов
decom.fit(X_scaled)
ex_var=np.cumsum(np.round(decom.explained_variance_ratio_,2))*100
sns.lineplot(y=ex_var, x=np.arange(0,len(ex_var)))
sns.scatterplot(y=ex_var, x=np.arange(0,len(ex_var)))

# %% [markdown]
# Как упоминалось выше, все функции независимы и не имеют какой-либо линейной зависимости, поэтому понадобилось бы по крайней мере 7 измерений, чтобы объяснить 90% вариаций. таким образом, уменьшение размерности не приводит к каким-либо изменениям.

# %%
#устранение дисбаланса в данных и масштабирование
from imblearn.over_sampling import SMOTE
samp = SMOTE()
X=df.drop(['Potability'], axis=1)
y=df['Potability']
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
X_train,X_test, y_train, y_test = train_test_split(X, y, random_state=42)
X_train, y_train =samp.fit_resample(X_train,y_train)

scale = StandardScaler()
X_train=scale.fit_transform(X_train)
X_test=scale.transform(X_test)

# %%
from yellowbrick.classifier import ROCAUC
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
mod = []
cv_score=[]
model =[AdaBoostClassifier(), BaggingClassifier(), GradientBoostingClassifier(), DecisionTreeClassifier(), ExtraTreeClassifier(), KNeighborsClassifier()]
for m in model:
    cv_score.append(cross_val_score(m, X_train, y_train, scoring='accuracy', cv=5).mean())
    mod.append(m)
model_df=pd.DataFrame(columns=['model','cv_score'])
model_df['model']=mod
model_df['cv_score']=cv_score
model_df.sort_values(by=['cv_score'], ascending=True).style.background_gradient(subset=['cv_score'])
# Out:
# <style type="text/css">
# #T_77b2a_row0_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_77b2a_row1_col1 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_77b2a_row2_col1 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_77b2a_row3_col1 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_77b2a_row4_col1 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_77b2a_row5_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_77b2a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >model</th>
#       <th class="col_heading level0 col1" >cv_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77b2a_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_77b2a_row0_col0" class="data row0 col0" >ExtraTreeClassifier()</td>
# ...

# %% [markdown]
# Исходя из приведенной выше базовой технологии моделирования, средний балл cv для GradientBoosting & BaggingClassifier высок по сравнению с другими моделями. итак, давайте попробуем выполнить гипернастройку для этих моделей, чтобы повысить точность

# %% [markdown]
# Попробуйте спрогнозировать отправку тестовых данных и определить точность модели

# %% [markdown]
# Настроим модели классификатора GradientBoosting & Bagging

# %%
param={'n_estimators': [60,70,80,100,200,300,400,500,600,700]}
grid_Grd=GridSearchCV(GradientBoostingClassifier(), param_grid=param, cv=5, scoring='accuracy')
grid_Grd.fit(X_train, y_train)
print(f"Best Estimator: {grid_Grd.best_params_} , Best Score : {grid_Grd.best_score_}")


param={'n_estimators': [60,70,80,100,200,300,400,500,600,700]}
grid_Bag=GridSearchCV(BaggingClassifier(), param_grid=param, cv=5, scoring='accuracy')
grid_Bag.fit(X_train, y_train)
print(f"Best Estimator: {grid_Bag.best_params_} , Best Score : {grid_Bag.best_score_}")
# Out:
# Best Estimator: {'n_estimators': 400} , Best Score : 0.7604128362754498
# Best Estimator: {'n_estimators': 70} , Best Score : 0.7788934634256387

# %% [markdown]
# Модели BaggingClassifier дают несколько более высокую точность, чем модель Gradientboosting. дальнейшая тонкая обработка могла бы повысить оценку точности. Остановлюсь здесь на рассмотрении вычислительного времени. давайте попробуем спрогнозировать тестовый набор данных с наилучшими параметрами из приведенной выше ячейки и построить матрицу путаницы и отчеты о классификации

# %% [markdown]
# Спрогнозируем отправку тестовых данных и определить точность модели

# %% [markdown]
# GradientBoosting/Градиентный рост

# %%
from sklearn.metrics import classification_report, confusion_matrix
model = GradientBoostingClassifier(n_estimators=300)
model.fit(X_train,y_train)
pred = model.predict(X_test)
print(classification_report(y_test, pred))
sns.heatmap(confusion_matrix(y_test, pred), annot=True, fmt='.2f')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.74      0.79       510
#            1       0.65      0.78      0.71       309
#
#     accuracy                           0.76       819
#    macro avg       0.75      0.76      0.75       819
# weighted avg       0.77      0.76      0.76       819

# %% [markdown]
# BaggingClassifier

# %%
from sklearn.metrics import classification_report, confusion_matrix
model = BaggingClassifier(n_estimators=80)
model.fit(X_train,y_train)
pred = model.predict(X_test)
print(classification_report(y_test, pred))
sns.heatmap(confusion_matrix(y_test, pred), annot=True, fmt='.2f')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.78      0.80       510
#            1       0.66      0.71      0.68       309
#
#     accuracy                           0.75       819
#    macro avg       0.74      0.74      0.74       819
# weighted avg       0.76      0.75      0.75       819

# %%
model.predict_proba(X_test)
# Out:
# array([[0.85  , 0.15  ],
#        [0.725 , 0.275 ],
#        [0.6875, 0.3125],
#        ...,
#        [0.025 , 0.975 ],
#        [0.65  , 0.35  ],
#        [0.5375, 0.4625]])

# %% [markdown]
# Попробуем с H2o AutoML

# %%
# !pip install h2o
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 177.2 MB 43 kB/s
# ...
#   Created wheel for h2o: filename=h2o-3.38.0.1-py2.py3-none-any.whl size=177276478 sha256=47fa61a144dd3abba71020f6e83429cdcc14b9f36713071a35139464d2ae3acd
#   Stored in directory: /root/.cache/pip/wheels/a1/a1/d9/bb37df368c4635a707e7362d1088450b606041f05aeba5f173
# Successfully built h2o
# ...

# %%
import h2o
from h2o.automl import H2OAutoML
h2o.init(max_mem_size='2G')
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.16" 2022-07-19; OpenJDK Runtime Environment (build 11.0.16+8-post-Ubuntu-0ubuntu118.04); OpenJDK 64-Bit Server VM (build 11.0.16+8-post-Ubuntu-0ubuntu118.04, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.7/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpku1fg0vh
#   JVM stdout: /tmp/tmpku1fg0vh/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpku1fg0vh/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         03 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.38.0.1
# H2O_cluster_version_age:    15 days
# ...

# %%
h2o_df = h2o.H2OFrame(df)
h2o_df['Potability']=h2o_df['Potability'].asfactor()
X=h2o_df.columns[0:-1]
y=h2o_df.columns[-1]
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
train, test=h2o_df.split_frame(ratios=[.7])
print(train.nrows)
print(test.nrows)
# Out:
# 2297
# 979

# %%
aml = H2OAutoML(balance_classes=True)
aml.train(x=X, y=y, training_frame=train)
# Out:
# AutoML progress: |███████████████████████████████████████████████████████████████| (done) 100%
# Model Details
# ...
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_BestOfFamily_6_AutoML_1_20221005_64614
#
# No summary for this model
#
# ModelMetricsBinomialGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.03324029374502312
# RMSE: 0.18231920838195606
# LogLoss: 0.1535616999225248
# AUC: 0.9994621595074388
# AUCPR: 0.9991485242310665
# Gini: 0.9989243190148775
# Null degrees of freedom: 2296
# Residual degrees of freedom: 2291
# Null deviance: 3066.9508027812913
# Residual deviance: 705.462449444079
# AIC: 717.462449444079
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.46171394211231026
#        0     1    Error    Rate
# -----  ----  ---  -------  -------------
# 0      1394  13   0.0092   (13.0/1407.0)
# 1      9     881  0.0101   (9.0/890.0)
# Total  1403  894  0.0096   (22.0/2297.0)
#
# ...

# %%
aml.leaderboard
# Out:
# model_id                                                                      auc    logloss     aucpr    mean_per_class_error      rmse       mse
# -----------------------------------------------------------------------  --------  ---------  --------  ----------------------  --------  --------
# StackedEnsemble_BestOfFamily_6_AutoML_1_20221005_64614                   0.868366   0.423875  0.833562                0.22609   0.374625  0.140344
# StackedEnsemble_BestOfFamily_4_AutoML_1_20221005_64614                   0.867045   0.425521  0.831322                0.230581  0.375569  0.141052
# StackedEnsemble_AllModels_6_AutoML_1_20221005_64614                      0.865272   0.422137  0.83138                 0.231969  0.375219  0.140789
# StackedEnsemble_AllModels_4_AutoML_1_20221005_64614                      0.865113   0.421843  0.830587                0.234276  0.375398  0.140924
# ...

# %%
type(test['Potability'])
# Out:
# h2o.frame.H2OFrame

# %%
pred = aml.leader.predict(test)
y_val = h2o.as_list(test['Potability'], use_pandas=True)
pred_val = h2o.as_list(pred['predict'], use_pandas=True)
print(classification_report(y_val,pred_val))
# Out:
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82       591
#            1       0.72      0.77      0.74       388
#
#     accuracy                           0.79       979
#    macro avg       0.78      0.79      0.78       979
# weighted avg       0.79      0.79      0.79       979

# %% [markdown]
# Оба алгоритма повышения градиента и пакетирования дают нам оценку f1 (сбалансированную с precision и recall) около 76%, а H2O AI дает нам точность 80% с помощью модели StackedEnsemble. В данном случае это хорошая модель для первоначального анализа, дальнейшая тонкая настройка и обработка выбросов могут способствовать повышению точности. Однако остановимся на этом рассмотрении времени вычислений.

# %% [markdown]
# ![wasser-19.jpg](data:image/jpeg;base64,...)
